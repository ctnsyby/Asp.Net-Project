# %% [markdown]
# <a href="https://colab.research.google.com/github/ctnsyby/Asp.Net-Project/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

resim1=cv2.imread('/content/gdrive/MyDrive/KodluyoruzBilgisayarlıGörü/Ekran Alıntısı.PNG')
plt.imshow(resim1)
plt.show()

# %%
resim2=cv2.cvtColor(resim1,cv2.COLOR_BGR2RGB)
plt.imshow(resim2)
plt.show()

# %%
print(resim2.shape)
# Out:
# (838, 627, 3)

# %%
renk =resim2[25,120]
print(renk)
# Out:
# [200 199 178]

# %%
kirmizi=resim2[25,120,0]
print('kirmizi:',kirmizi)

yesil=resim2[25,120,1]
print('yesil:',yesil)

mavi=resim2[25,120,2]
print('mavi:',mavi)
# Out:
# kirmizi: 200
# yesil: 199
# mavi: 178

# %%
resim2[25,120,1]=255
print('yeni yesil degeri :', resim2[25,120,1])
# Out:
# yeni yesil degeri : 255
